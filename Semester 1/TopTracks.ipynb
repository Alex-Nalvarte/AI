# %% [markdown]
# # Which artist had the most songs on the US chart in 2024 and how did they compare to the Global chart in 2024?

# %% [markdown]
# I plan to look at the whole playlist for the US and Global chart and take a look at the whole population, not just a sample of it in order to determine which artist had the most songs for the US charts and how they compared to the Global charts. This study will be an observational study, since I am not changing variables that will change the data. This data comes directly from the spotify USA 2024 and Global 2024 charts. It features the track name, the artist, the genre wikipedia gave the song, and the genre AI gave the song. Some biases that may be produced by the data are

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
global_data = pd.read_csv('global.csv')
freq_table = df["Artist"].value_counts().reset_index()
freq_table.columns =["Artist", "Count"]

# %%
total = freq_table["Count"].sum()

# %%
freq_table['Relative_Frequency'] = freq_table['Count'] / total
freq_table['Percentage'] = freq_table['Relative_Frequency'] * 100

# %%
frequency_counts = global_data["Artist"].value_counts()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=freq_table, x="Artist", y='Relative_Frequency')
plt.title('Frequency Distribution of USA Spotify Chart')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="Artist", data=global_data, palette='viridis')
plt.title('Frequency Distribution of Global Spotify Chart')
plt.xlabel("Artist")
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.tight_layout()

# %% [markdown]
# Sabrina Carpenter appears most frequently on the top 50 US Spotify Charts, with four songs in the playlist (8 percent of the whole playlist). She also ties for the first spot on the global chart with Billie Eilish and Sza, with each of them having 2 songs in the Top 50 Global Playlist (4 Percent of the whole playlist each)
